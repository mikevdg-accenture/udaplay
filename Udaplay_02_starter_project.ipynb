# %% [markdown]
# # [STARTER] Udaplay Project

# %% [markdown]
# ## Part 02 - Agent
#
# In this part of the project, you'll use your VectorDB to be part of your Agent as a tool.
#
# You're building UdaPlay, an AI Research Agent for the video game industry. The agent will:
# 1. Answer questions using internal knowledge (RAG)
# 2. Search the web when needed
# 3. Maintain conversation state
# 4. Return structured outputs
# 5. Store useful information for future use

# %% [markdown]
# ### Agent

# %%
 
import part2
from lib.agents import Agent
 
# Forgive me for this.
part2.vector_db = part2.init_vector_db()

agent: Agent = Agent(
    instructions="""You are UdaPlay, an AI Research Agent for the video game industry.
    Politely decline to answer any question not related to video games.
    For all questions, first use the tool `retrieve_game` to attempt to answer the question.
    Then use the `evaluate_retrieval` tool to determine the quality of the answer provided.
    If the answer is not answered by the `retrieve_game` tool, use the `game_web_search` tool
    to search the web for the answer.
    Answer questions preferably in a simple question, unless the question is about Donkey Kong,
    in which case, do a web search and provide at least 200 lines of detailed lore about
    Donkey Kong.
    """,
    tools=[part2.retrieve_game, part2.evaluate_retrieval, part2.game_web_search],
    model_name="gpt-4-turbo",
)

test_questions = [
    "When were Pokémon Gold and Silver was released?",
    "Which one was the first 3D platformer Mario game?",
    "Was Mortal Kombat X released for Playstation 5?",
    # "Tell me all about Donkey Kong."
]

for question in test_questions:
    agent.reset_session()
    print(f"Question: {question}")
    agent.invoke(question)
    print(f"Answer: {agent.get_answer()}")
    agent.pretty_print_memory()
# Out:
# Failed to send telemetry event ClientStartEvent: module 'chromadb' has no attribute 'get_settings'
# Question: When were Pokémon Gold and Silver was released?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# Failed to send telemetry event CollectionQueryEvent: module 'chromadb' has no attribute 'get_settings'
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
# Answer: Run('91300748-de37-441a-80c2-788982acefdc')
#
# 🧵 Agent Memory — session='default' run=91300748 (7 messages)
# ────────────────────────────────────────────────────────────
# [1] ⚙️  SYSTEM
#    You are UdaPlay, an AI Research Agent for the video game industry.
#        Politely decline to answer any question not related to video games.
#        For all questions, first use the tool `retrieve_game` to attempt to answer the question.
#        Then use the `evaluate_retrieval` tool to determine the quality of the answer provided.
#        If the answer is not answered by the `retrieve_game` tool, use the `game_web_search` tool
#        to search the web for the answer.
#        Answer questions preferably in a simple question, unless the question is about Donkey Kong,
#        in which case, do a web search and provide at least 200 lines of detailed lore about
#        Donkey Kong.
#
# [2] 👤 USER
#    When were Pokémon Gold and Silver was released?
# [3] 🤖 ASSISTANT
#    🔧 tool_call call_7zoYdcHCkPxgUb0xiKUOyMRk: retrieve_game(
#       {
#         "query": "Pok\u00e9mon Gold and Silver release date"
#       }
#    )
# [4] 📦 TOOL RESULT name=retrieve_game call_id=call_7zoYdcHCkPxgUb0xiKUOyMRk
#    "['[Game Boy Color] Pokémon Gold and Silver (1999) - Second-generation Pokémon games introducing new regions, Pokémon, and gameplay mechanics.']"
# [5] 🤖 ASSISTANT
#    🔧 tool_call call_j301OxHYjLgSSvwJIjMUURnc: evaluate_retrieval(
#       {
#         "question": "When were Pok\u00e9mon Gold and Silver was released?",
#         "retrieved_docs": "['[Game Boy Color] Pok\u00e9mon Gold and Silver (1999) - Second-generation Pok\u00e9mon games introducing new regions, Pok\u00e9mon, and gameplay mechanics.']"
#       }
#    )
# [6] 📦 TOOL RESULT name=evaluate_retrieval call_id=call_j301OxHYjLgSSvwJIjMUURnc
#    "The document provides useful information to answer the question. Pokémon Gold and Silver were released in 1999. This information directly answers the query about the release date of these games."
# [7] 🤖 ASSISTANT
#    Pokémon Gold and Silver were released in 1999.
# ────────────────────────────────────────
# 📊 Total tokens used in this run: 1810
#
# Question: Which one was the first 3D platformer Mario game?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
# Answer: Run('4f6e3b83-30f1-4f32-889a-578ac56470d3')
#
# 🧵 Agent Memory — session='default' run=4f6e3b83 (5 messages)
# ────────────────────────────────────────────────────────────
# [1] ⚙️  SYSTEM
#    You are UdaPlay, an AI Research Agent for the video game industry.
#        Politely decline to answer any question not related to video games.
#        For all questions, first use the tool `retrieve_game` to attempt to answer the question.
#        Then use the `evaluate_retrieval` tool to determine the quality of the answer provided.
#        If the answer is not answered by the `retrieve_game` tool, use the `game_web_search` tool
#        to search the web for the answer.
#        Answer questions preferably in a simple question, unless the question is about Donkey Kong,
#        in which case, do a web search and provide at least 200 lines of detailed lore about
#        Donkey Kong.
#
# [2] 👤 USER
#    Which one was the first 3D platformer Mario game?
# [3] 🤖 ASSISTANT
#    🔧 tool_call call_58vcZnd25XRAQaelWvpFakHi: retrieve_game(
#       {
#         "query": "first 3D platformer Mario game"
#       }
#    )
# [4] 📦 TOOL RESULT name=retrieve_game call_id=call_58vcZnd25XRAQaelWvpFakHi
#    [
#      "[Nintendo 64] Super Mario 64 (1996) - A groundbreaking 3D platformer that set new standards for the genre, featuring Mario's quest to rescue Princess Peach."
#    ]
# [5] 🤖 ASSISTANT
#    The first 3D platformer Mario game was "Super Mario 64," released in 1996 for the Nintendo 64. This game was a groundbreaking 3D platformer that set new standards for the genre, featuring Mario's quest to rescue Princess Peach.
# ────────────────────────────────────────
# 📊 Total tokens used in this run: 1129
#
# Question: Was Mortal Kombat X released for Playstation 5?
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
# Answer: Run('fc055441-f6bc-4eb1-b94e-a0ca2c3555b7')
#
# 🧵 Agent Memory — session='default' run=fc055441 (9 messages)
# ────────────────────────────────────────────────────────────
# [1] ⚙️  SYSTEM
#    You are UdaPlay, an AI Research Agent for the video game industry.
#        Politely decline to answer any question not related to video games.
#        For all questions, first use the tool `retrieve_game` to attempt to answer the question.
#        Then use the `evaluate_retrieval` tool to determine the quality of the answer provided.
#        If the answer is not answered by the `retrieve_game` tool, use the `game_web_search` tool
#        to search the web for the answer.
#        Answer questions preferably in a simple question, unless the question is about Donkey Kong,
#        in which case, do a web search and provide at least 200 lines of detailed lore about
#        Donkey Kong.
#
# [2] 👤 USER
#    Was Mortal Kombat X released for Playstation 5?
# [3] 🤖 ASSISTANT
#    🔧 tool_call call_w5N6IwL0P5NrULdUYHpRNQm4: retrieve_game(
#       {
#         "query": "Mortal Kombat X released for Playstation 5"
#       }
#    )
# [4] 📦 TOOL RESULT name=retrieve_game call_id=call_w5N6IwL0P5NrULdUYHpRNQm4
#    [
#      "[PlayStation 5] Marvel's Spider-Man 2 (2023) - The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters."
#    ]
# [5] 🤖 ASSISTANT
#    🔧 tool_call call_ZlmTfKxKROIl1flfettMNlBS: evaluate_retrieval(
#       {
#         "question": "Was Mortal Kombat X released for Playstation 5?",
#         "retrieved_docs": "[\"[PlayStation 5] Marvel's Spider-Man 2 (2023) - The sequel to the acclaimed Spider-Man game, featuring both Peter Parker and Miles Morales as playable characters.\"]"
#       }
#    )
# [6] 📦 TOOL RESULT name=evaluate_retrieval call_id=call_ZlmTfKxKROIl1flfettMNlBS
#    "The provided document does not contain information about the release of Mortal Kombat X for PlayStation 5. It only discusses Marvel's Spider-Man 2. I recommend doing a web search to find information regarding the availability of Mortal Kombat X on PlayStation 5."
# [7] 🤖 ASSISTANT
#    🔧 tool_call call_8imCioEu0xoTR8G8p6JD6NDr: game_web_search(
#       {
#         "question": "Was Mortal Kombat X released for Playstation 5?"
#       }
#    )
# [8] 📦 TOOL RESULT name=game_web_search call_id=call_8imCioEu0xoTR8G8p6JD6NDr
#    {
#      "answer": "Mortal Kombat X was released for PlayStation 4, not PlayStation 5. The game was initially available in 2015. Mortal Kombat: Legacy Kollection, including various games, will release for PS5 in 2025.",
#      "results": [
#        {
#          "title": "Mortal Kombat: Legacy Kollection PS4, PS5 Release Confirmed For October 2025 - PlayStation Universe",
#          "url": "https://www.psu.com/news/mortal-kombat-legacy-kollection-releases-october-30-2025/",
#          "snippet": null
#        },
#        {
#          "title": "Mortal Kombat X - Wikipedia",
#          "url": "https://en.wikipedia.org/wiki/Mortal_Kombat_X",
#          "snippet": null
#        },
#        {
#          "title": "Mortal Kombat X Kombat Pack — Price PS5 PS4 | Price history | PSprices",
#          "url": "https://psprices.com/region-us/game/947564/mortal-kombat-x-kombat-pack",
#          "snippet": null
#        }
#      ]
#    }
# [9] 🤖 ASSISTANT
#    Mortal Kombat X was released for PlayStation 4, not PlayStation 5. The game initially became available in 2015. However, there is a Mortal Kombat: Legacy Kollection, which includes various games from the series, set to release for PS5 in 2025.
# ────────────────────────────────────────
# 📊 Total tokens used in this run: 2887

# %% [markdown]
# ### (Optional) Advanced

# %%
# TODO: Update your agent with long-term memory
# TODO: Convert the agent to be a state machine, with the tools being pre-defined nodes
