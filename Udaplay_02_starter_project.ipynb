# %% [markdown]
# # [STARTER] Udaplay Project

# %% [markdown]
# ## Part 02 - Agent
#
# In this part of the project, you'll use your VectorDB to be part of your Agent as a tool.
#
# You're building UdaPlay, an AI Research Agent for the video game industry. The agent will:
# 1. Answer questions using internal knowledge (RAG)
# 2. Search the web when needed
# 3. Maintain conversation state
# 4. Return structured outputs
# 5. Store useful information for future use

# %% [markdown]
# ### Agent

# %%
 
import part2
part2.run_project()
# Out:
# PART 01 - OFFLINE RAG: Setting up Vector Database
#
# Loading environment variables...
# Initializing ChromaDB client...
# Creating embedding function with OpenAI...
#   API Base URL: https://openai.vocareum.com/v1
#   API Key set: True
# Creating 'udaplay' collection...
# Using existing 'udaplay' collection...
# Loading games from 'games' directory and adding to collection...
#   ✓ Added: Gran Turismo (PlayStation 1, 1997)
#   ✓ Added: Grand Theft Auto: San Andreas (PlayStation 2, 2004)
#   ✓ Added: Gran Turismo 5 (PlayStation 3, 2010)
#   ✓ Added: Marvel's Spider-Man (PlayStation 4, 2018)
#   ✓ Added: Marvel's Spider-Man 2 (PlayStation 5, 2023)
#   ✓ Added: Pokémon Gold and Silver (Game Boy Color, 1999)
#   ✓ Added: Pokémon Ruby and Sapphire (Game Boy Advance, 2002)
#   ✓ Added: Super Mario World (Super Nintendo Entertainment System (SNES), 1990)
#   ✓ Added: Super Mario 64 (Nintendo 64, 1996)
#   ✓ Added: Super Smash Bros. Melee (GameCube, 2001)
#   ✓ Added: Wii Sports (Wii, 2006)
#   ✓ Added: Mario Kart 8 Deluxe (Nintendo Switch, 2017)
#   ✓ Added: Kinect Adventures! (Xbox 360, 2010)
#   ✓ Added: Minecraft (Xbox One, 2014)
#   ✓ Added: Halo Infinite (Xbox Series X|S, 2021)
# Successfully added 15 games to the collection!
# Part 01 Complete: Vector Database is ready!
# Question: When were Pokémon Gold and Silver was released?
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import part2
# ----> 2 part2.run_project()
#
# File /workspace/Code/part2.py:186, in run_project()
#     183     print(f"Question: {question}")
#     185     # agent.invoke() uses a state machine as per the project rubric.
# --> 186     agent.invoke(question)
#     187     print(f"Answer: {agent.get_answer()}\n")
#     189 agent.pretty_print_memory()
#
# File /workspace/Code/lib/agents.py:205, in Agent.invoke(self, query, session_id)
#     195         previous_messages = last_state["messages"]
#     197 initial_state: AgentState = {
#     198     "user_query": query,
#     199     "instructions": self.instructions,
#    (...)    202     "session_id": session_id,
#     203 }
# --> 205 run_object = self.workflow.run(initial_state)
#     207 # Store the complete run object in memory
#     208 self.memory.add(run_object, session_id)
#
# File /workspace/Code/lib/state_machine.py:260, in StateMachine.run(self, state, resource)
#     257     break
#     259 # Replace state entirely
# --> 260 state = step.run(state, self.state_schema, resource)
#     262 # Create and add snapshot to the current run
#     263 snapshot = Snapshot.create(
#     264     copy.deepcopy(state), self.state_schema, current_step_id
#     265 )
#
# File /workspace/Code/lib/state_machine.py:59, in Step.run(self, state, state_schema, resource)
#      51 def run(
#      52     self,
#      53     state: StateSchema,
#    (...)     56 ) -> StateSchema:
#      57     # Call logic function with appropriate number of arguments
#      58     if self.logic_params_count == 1:
# ---> 59         result = self.logic(state)
#      60     elif self.logic_params_count == 2:
#      61         result = self.logic(state, resource)
#
# File /workspace/Code/lib/agents.py:123, in Agent._evaluate_step(self, state)
#     114 def _evaluate_step(self, state: AgentState) -> AgentState:
#     115     evaluation_agent: Agent = Agent(
#     116         instructions="""
#     117         Your task is to evaluate whether retrieved documents are useful in answering the given question.
#    (...)    120         """
#     121     )
# --> 123     question : str = state.messages[-1].content
#     124     print("Content: "+content)
#     125     agent_query = {question: question, retrieved_docs: str(retrieved_docs)}
#
# AttributeError: 'dict' object has no attribute 'messages'
