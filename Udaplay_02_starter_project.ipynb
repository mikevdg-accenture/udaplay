# %% [markdown]
# # [STARTER] Udaplay Project

# %% [markdown]
# ## Part 02 - Agent
#
# In this part of the project, you'll use your VectorDB to be part of your Agent as a tool.
#
# You're building UdaPlay, an AI Research Agent for the video game industry. The agent will:
# 1. Answer questions using internal knowledge (RAG)
# 2. Search the web when needed
# 3. Maintain conversation state
# 4. Return structured outputs
# 5. Store useful information for future use

# %% [markdown]
# ### Agent

# %%
 
import part2
part2.run_project()
# Out:
# PART 01 - OFFLINE RAG: Setting up Vector Database
#
# Loading environment variables...
# Initializing ChromaDB client...
# Creating embedding function with OpenAI...
#   API Base URL: https://openai.vocareum.com/v1
#   API Key set: True
# Creating 'udaplay' collection...
# Using existing 'udaplay' collection...
# Loading games from 'games' directory and adding to collection...
#   ✓ Added: Gran Turismo (PlayStation 1, 1997)
#   ✓ Added: Grand Theft Auto: San Andreas (PlayStation 2, 2004)
#   ✓ Added: Gran Turismo 5 (PlayStation 3, 2010)
#   ✓ Added: Marvel's Spider-Man (PlayStation 4, 2018)
#   ✓ Added: Marvel's Spider-Man 2 (PlayStation 5, 2023)
#   ✓ Added: Pokémon Gold and Silver (Game Boy Color, 1999)
#   ✓ Added: Pokémon Ruby and Sapphire (Game Boy Advance, 2002)
#   ✓ Added: Super Mario World (Super Nintendo Entertainment System (SNES), 1990)
#   ✓ Added: Super Mario 64 (Nintendo 64, 1996)
#   ✓ Added: Super Smash Bros. Melee (GameCube, 2001)
#   ✓ Added: Wii Sports (Wii, 2006)
#   ✓ Added: Mario Kart 8 Deluxe (Nintendo Switch, 2017)
#   ✓ Added: Kinect Adventures! (Xbox 360, 2010)
#   ✓ Added: Minecraft (Xbox One, 2014)
#   ✓ Added: Halo Infinite (Xbox Series X|S, 2021)
# Successfully added 15 games to the collection!
# Part 01 Complete: Vector Database is ready!
# Question: When were Pokémon Gold and Silver was released?
# Answer: Pokémon Gold and Silver were released in 1999 for the Game Boy Color.
# Citation: internal database.
#
# Question: Which one was the first 3D platformer Mario game?
# Answer: The first 3D platformer Mario game is "Super Mario 64," released in 1996 for the Nintendo 64.
# Citation: internal database.
#
# Question: Was Mortal Kombat X released for Playstation 5?
# Answer: Mortal Kombat X was released for PlayStation 4 in 2015, not for PlayStation 5.
# Citation: [PSprices](https://psprices.com/region-us/game/947564/mortal-kombat-x-kombat-pack)
#
#
# 🧵 Agent Memory — session='default' run=0fc2f62c (15 messages)
# ─────────────────────────────────────────────────────────────
# [ 1] ⚙️ SYSTEM      You are UdaPlay, an AI Research Agent for the video game ...
# [ 2] 👤 USER        When were Pokémon Gold and Silver was released?
# [ 3] 🔧 TOOL CALL   retrieve_game({"query":"Pokémon Gold and Silver release d...
# [ 4] 📦 TOOL RESULT [retrieve_game] "['[Game Boy Color] Pok\u00e9mon Gold and...
# [ 5] 🤖 ASSISTANT   Pokémon Gold and Silver were released in 1999 for the Gam...
# [ 6] 👤 USER        Which one was the first 3D platformer Mario game?
# [ 7] 🔧 TOOL CALL   retrieve_game({"query":"first 3D platformer Mario game"})
# [ 8] 📦 TOOL RESULT [retrieve_game] ["[Nintendo 64] Super Mario 64 (1996) - A...
# [ 9] 🤖 ASSISTANT   The first 3D platformer Mario game is "Super Mario 64," r...
# [10] 👤 USER        Was Mortal Kombat X released for Playstation 5?
# [11] 🔧 TOOL CALL   retrieve_game({"query":"Mortal Kombat X Playstation 5"})
# [12] 📦 TOOL RESULT [retrieve_game] ["[PlayStation 5] Marvel's Spider-Man 2 (...
# [13] 🔧 TOOL CALL   game_web_search({"question":"Was Mortal Kombat X released...
# [14] 📦 TOOL RESULT [game_web_search] {"answer": "Mortal Kombat X was release...
# [15] 🤖 ASSISTANT   Mortal Kombat X was released for PlayStation 4 in 2015, n...
# ────────────────────────────────────────
# 📊 Total tokens used in this run: 2614
