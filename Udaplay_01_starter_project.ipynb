# %% [markdown]
# # Udaplay Project

# %% [markdown]
# ## Part 01 - Offline RAG
#
# In this part of the project, you'll build your VectorDB using Chroma.
#
# The data is inside folder `project/starter/games`. Each file will become a document in the collection you'll create.
# Example.:
# ```json
# {
#   "Name": "Gran Turismo",
#   "Platform": "PlayStation 1",
#   "Genre": "Racing",
#   "Publisher": "Sony Computer Entertainment",
#   "Description": "A realistic racing simulator featuring a wide array of cars and tracks, setting a new standard for the genre.",
#   "YearOfRelease": 1997
# }
# ```

# %%
import importlib.util
import sys
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3

    sys.modules["sqlite3"] = sys.modules.pop("pysqlite3")

# %%
import part1
vector_db = part1.setup_vector_db()
# Out:
# PART 01 - OFFLINE RAG: Setting up Vector Database
#
# Loading environment variables...
# Initializing ChromaDB client...
# Creating embedding function with OpenAI...
#   API Base URL: https://openai.vocareum.com/v1
#   API Key set: True
# Creating 'udaplay' collection...
# Created new 'udaplay' collection...
# Loading games from 'games' directory and adding to collection...
#   ✓ Added: Gran Turismo (PlayStation 1, 1997)
#   ✓ Added: Grand Theft Auto: San Andreas (PlayStation 2, 2004)
#   ✓ Added: Gran Turismo 5 (PlayStation 3, 2010)
#   ✓ Added: Marvel's Spider-Man (PlayStation 4, 2018)
#   ✓ Added: Marvel's Spider-Man 2 (PlayStation 5, 2023)
#   ✓ Added: Pokémon Gold and Silver (Game Boy Color, 1999)
#   ✓ Added: Pokémon Ruby and Sapphire (Game Boy Advance, 2002)
#   ✓ Added: Super Mario World (Super Nintendo Entertainment System (SNES), 1990)
#   ✓ Added: Super Mario 64 (Nintendo 64, 1996)
#   ✓ Added: Super Smash Bros. Melee (GameCube, 2001)
#   ✓ Added: Wii Sports (Wii, 2006)
#   ✓ Added: Mario Kart 8 Deluxe (Nintendo Switch, 2017)
#   ✓ Added: Kinect Adventures! (Xbox 360, 2010)
#   ✓ Added: Minecraft (Xbox One, 2014)
#   ✓ Added: Halo Infinite (Xbox Series X|S, 2021)
# Successfully added 15 games to the collection!
# Part 01 Complete: Vector Database is ready!
